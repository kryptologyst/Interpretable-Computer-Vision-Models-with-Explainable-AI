# %% [markdown]
# # Interpretable Computer Vision with XAI
#
# This notebook demonstrates how to use the interpretable computer vision XAI package to:
#
# 1. Train a simple CNN model on CIFAR-10
# 2. Generate explanations using multiple XAI methods
# 3. Evaluate explanation quality
# 4. Visualize results
#
# ## Important Disclaimer
#
# **This notebook is for research and educational purposes only.**
# - XAI outputs may be unstable or misleading
# - Not a substitute for human judgment
# - Do not use for regulated decisions without human review
